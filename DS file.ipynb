# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('~/Desktop/coursework/Olympic_Games.csv')

# %%
data.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball   NaN
# 1        Judo Men's Extra-Lightweight   NaN
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# 6    Speed Skating Women's 500 metres   NaN
# 7  Speed Skating Women's 1,000 metres   NaN
# 8    Speed Skating Women's 500 metres   NaN
# 9  Speed Skating Women's 1,000 metres   NaN

# %%
data.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping Men's Large Hill, Individual   NaN
# 271113        Ski Jumping Men's Large Hill, Team   NaN
# 271114                      Bobsleigh Men's Four   NaN
# 271115                      Bobsleigh Men's Four   NaN

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
data.shape
# Out:
# (271116, 15)

# %%
data.size
# Out:
# 4066740

# %%
data.ndim
# Out:
# 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
pd.isnull(data)
# Out:
#            ID   Name    Sex    Age  Height  Weight   Team    NOC  Games  \
# 0       False  False  False  False   False   False  False  False  False
# 1       False  False  False  False   False   False  False  False  False
# 2       False  False  False  False    True    True  False  False  False
# 3       False  False  False  False    True    True  False  False  False
# 4       False  False  False  False   False   False  False  False  False
# ...       ...    ...    ...    ...     ...     ...    ...    ...    ...
# 271111  False  False  False  False   False   False  False  False  False
# 271112  False  False  False  False   False   False  False  False  False
# 271113  False  False  False  False   False   False  False  False  False
# 271114  False  False  False  False   False   False  False  False  False
# 271115  False  False  False  False   False   False  False  False  False
#
#          Year  Season   City  Sport  Event  Medal
# 0       False   False  False  False  False   True
# 1       False   False  False  False  False   True
# 2       False   False  False  False  False   True
# 3       False   False  False  False  False  False
# 4       False   False  False  False  False   True
# ...       ...     ...    ...    ...    ...    ...
# 271111  False   False  False  False  False   True
# 271112  False   False  False  False  False   True
# 271113  False   False  False  False  False   True
# 271114  False   False  False  False  False   True
# 271115  False   False  False  False  False   True
#
# [271116 rows x 15 columns]

# %%
print(data.isnull().sum())
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
pk = pd.DataFrame(data)

# %%
# Remove column names ‘ID’,‘Name’,‘Team’,‘Games’ and ‘City’
pk = pk.drop(['ID','Name','Team','Games' and 'City'], axis=1)
print(pk)
# Out:
#        Sex   Age  Height  Weight  NOC        Games  Year  Season  \
# 0        M  24.0   180.0    80.0  CHN  1992 Summer  1992  Summer
# 1        M  23.0   170.0    60.0  CHN  2012 Summer  2012  Summer
# 2        M  24.0     NaN     NaN  DEN  1920 Summer  1920  Summer
# 3        M  34.0     NaN     NaN  DEN  1900 Summer  1900  Summer
# 4        F  21.0   185.0    82.0  NED  1988 Winter  1988  Winter
# ...     ..   ...     ...     ...  ...          ...   ...     ...
# 271111   M  29.0   179.0    89.0  POL  1976 Winter  1976  Winter
# 271112   M  27.0   176.0    59.0  POL  2014 Winter  2014  Winter
# 271113   M  27.0   176.0    59.0  POL  2014 Winter  2014  Winter
# 271114   M  30.0   185.0    96.0  POL  1998 Winter  1998  Winter
# 271115   M  34.0   185.0    96.0  POL  2002 Winter  2002  Winter
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 11 columns]

# %%
# remove all the rows which have ‘NA’ in the ‘Medal’ column.
pk = pk.dropna(subset=['Medal'])
print(pk)
# Out:
#        Sex   Age  Height  Weight  NOC        Games  Year  Season       Sport  \
# 3        M  34.0     NaN     NaN  DEN  1900 Summer  1900  Summer  Tug-Of-War
# 37       M  30.0     NaN     NaN  FIN  1920 Summer  1920  Summer    Swimming
# 38       M  30.0     NaN     NaN  FIN  1920 Summer  1920  Summer    Swimming
# 40       M  28.0   184.0    85.0  FIN  2014 Winter  2014  Winter  Ice Hockey
# 41       M  28.0   175.0    64.0  FIN  1948 Summer  1948  Summer  Gymnastics
# ...     ..   ...     ...     ...  ...          ...   ...     ...         ...
# 271078   F  25.0   168.0    80.0  URS  1956 Summer  1956  Summer   Athletics
# 271080   F  33.0   168.0    80.0  URS  1964 Summer  1964  Summer   Athletics
# 271082   M  28.0   182.0    82.0  POL  1980 Summer  1980  Summer     Fencing
# 271102   F  19.0   171.0    64.0  RUS  2000 Summer  2000  Summer   Athletics
# 271103   F  23.0   171.0    64.0  RUS  2004 Summer  2004  Summer   Athletics
#
#                                          Event   Medal
# 3                  Tug-Of-War Men's Tug-Of-War    Gold
# 37      Swimming Men's 200 metres Breaststroke  Bronze
# 38      Swimming Men's 400 metres Breaststroke  Bronze
# 40                 Ice Hockey Men's Ice Hockey  Bronze
# 41      Gymnastics Men's Individual All-Around  Bronze
# ...                                        ...     ...
# 271078              Athletics Women's Shot Put  Silver
# 271080              Athletics Women's Shot Put  Bronze
# 271082                Fencing Men's Foil, Team  Bronze
# 271102  Athletics Women's 4 x 400 metres Relay  Bronze
# 271103  Athletics Women's 4 x 400 metres Relay  Silver
#
# [39783 rows x 11 columns]

# %%
# In the ‘Sex’ column, convert all of the ‘M’s to 0 and ‘F’s to 1.
pk['Sex'].replace({"M": 1, "F": 0}, inplace=True)
print(pk)
# Out:
#         Sex   Age  Height  Weight  NOC        Games  Year  Season       Sport  \
# 3         1  34.0     NaN     NaN  DEN  1900 Summer  1900  Summer  Tug-Of-War
# 37        1  30.0     NaN     NaN  FIN  1920 Summer  1920  Summer    Swimming
# 38        1  30.0     NaN     NaN  FIN  1920 Summer  1920  Summer    Swimming
# 40        1  28.0   184.0    85.0  FIN  2014 Winter  2014  Winter  Ice Hockey
# 41        1  28.0   175.0    64.0  FIN  1948 Summer  1948  Summer  Gymnastics
# ...     ...   ...     ...     ...  ...          ...   ...     ...         ...
# 271078    0  25.0   168.0    80.0  URS  1956 Summer  1956  Summer   Athletics
# 271080    0  33.0   168.0    80.0  URS  1964 Summer  1964  Summer   Athletics
# 271082    1  28.0   182.0    82.0  POL  1980 Summer  1980  Summer     Fencing
# 271102    0  19.0   171.0    64.0  RUS  2000 Summer  2000  Summer   Athletics
# 271103    0  23.0   171.0    64.0  RUS  2004 Summer  2004  Summer   Athletics
#
#                                          Event   Medal
# 3                  Tug-Of-War Men's Tug-Of-War    Gold
# 37      Swimming Men's 200 metres Breaststroke  Bronze
# 38      Swimming Men's 400 metres Breaststroke  Bronze
# 40                 Ice Hockey Men's Ice Hockey  Bronze
# 41      Gymnastics Men's Individual All-Around  Bronze
# ...                                        ...     ...
# 271078              Athletics Women's Shot Put  Silver
# 271080              Athletics Women's Shot Put  Bronze
# 271082                Fencing Men's Foil, Team  Bronze
# 271102  Athletics Women's 4 x 400 metres Relay  Bronze
# 271103  Athletics Women's 4 x 400 metres Relay  Silver
#
# [39783 rows x 11 columns]

# %%
# In the ‘Season’ column, convert all of the ‘Summer’s to 0 and all of the ’Winter’s to 1.
pk['Season'].replace({"Summer": 0, "Winter": 1}, inplace=True)
print(pk)
# Out:
#         Sex   Age  Height  Weight  NOC        Games  Year  Season       Sport  \
# 3         1  34.0     NaN     NaN  DEN  1900 Summer  1900       0  Tug-Of-War
# 37        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 38        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 40        1  28.0   184.0    85.0  FIN  2014 Winter  2014       1  Ice Hockey
# 41        1  28.0   175.0    64.0  FIN  1948 Summer  1948       0  Gymnastics
# ...     ...   ...     ...     ...  ...          ...   ...     ...         ...
# 271078    0  25.0   168.0    80.0  URS  1956 Summer  1956       0   Athletics
# 271080    0  33.0   168.0    80.0  URS  1964 Summer  1964       0   Athletics
# 271082    1  28.0   182.0    82.0  POL  1980 Summer  1980       0     Fencing
# 271102    0  19.0   171.0    64.0  RUS  2000 Summer  2000       0   Athletics
# 271103    0  23.0   171.0    64.0  RUS  2004 Summer  2004       0   Athletics
#
#                                          Event   Medal
# 3                  Tug-Of-War Men's Tug-Of-War    Gold
# 37      Swimming Men's 200 metres Breaststroke  Bronze
# 38      Swimming Men's 400 metres Breaststroke  Bronze
# 40                 Ice Hockey Men's Ice Hockey  Bronze
# 41      Gymnastics Men's Individual All-Around  Bronze
# ...                                        ...     ...
# 271078              Athletics Women's Shot Put  Silver
# 271080              Athletics Women's Shot Put  Bronze
# 271082                Fencing Men's Foil, Team  Bronze
# 271102  Athletics Women's 4 x 400 metres Relay  Bronze
# 271103  Athletics Women's 4 x 400 metres Relay  Silver
#
# [39783 rows x 11 columns]

# %%
# In the ’Medal’ column, convert all of the ‘Gold’s to 3, all of the ‘Silver’s to 2, all of the ‘Bronze’s to 1.
pk['Medal'].replace({"Gold": 3, "Silver": 2, "Bronze": 1}, inplace=True)
print(pk)
# Out:
#         Sex   Age  Height  Weight  NOC        Games  Year  Season       Sport  \
# 3         1  34.0     NaN     NaN  DEN  1900 Summer  1900       0  Tug-Of-War
# 37        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 38        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 40        1  28.0   184.0    85.0  FIN  2014 Winter  2014       1  Ice Hockey
# 41        1  28.0   175.0    64.0  FIN  1948 Summer  1948       0  Gymnastics
# ...     ...   ...     ...     ...  ...          ...   ...     ...         ...
# 271078    0  25.0   168.0    80.0  URS  1956 Summer  1956       0   Athletics
# 271080    0  33.0   168.0    80.0  URS  1964 Summer  1964       0   Athletics
# 271082    1  28.0   182.0    82.0  POL  1980 Summer  1980       0     Fencing
# 271102    0  19.0   171.0    64.0  RUS  2000 Summer  2000       0   Athletics
# 271103    0  23.0   171.0    64.0  RUS  2004 Summer  2004       0   Athletics
#
#                                          Event  Medal
# 3                  Tug-Of-War Men's Tug-Of-War      3
# 37      Swimming Men's 200 metres Breaststroke      1
# 38      Swimming Men's 400 metres Breaststroke      1
# 40                 Ice Hockey Men's Ice Hockey      1
# 41      Gymnastics Men's Individual All-Around      1
# ...                                        ...    ...
# 271078              Athletics Women's Shot Put      2
# 271080              Athletics Women's Shot Put      1
# 271082                Fencing Men's Foil, Team      1
# 271102  Athletics Women's 4 x 400 metres Relay      1
# 271103  Athletics Women's 4 x 400 metres Relay      2
#
# [39783 rows x 11 columns]

# %%
pk.head(10)
# Out:
#     Sex   Age  Height  Weight  NOC        Games  Year  Season          Sport  \
# 3     1  34.0     NaN     NaN  DEN  1900 Summer  1900       0     Tug-Of-War
# 37    1  30.0     NaN     NaN  FIN  1920 Summer  1920       0       Swimming
# 38    1  30.0     NaN     NaN  FIN  1920 Summer  1920       0       Swimming
# 40    1  28.0   184.0    85.0  FIN  2014 Winter  2014       1     Ice Hockey
# 41    1  28.0   175.0    64.0  FIN  1948 Summer  1948       0     Gymnastics
# 42    1  28.0   175.0    64.0  FIN  1948 Summer  1948       0     Gymnastics
# 44    1  28.0   175.0    64.0  FIN  1948 Summer  1948       0     Gymnastics
# 48    1  28.0   175.0    64.0  FIN  1948 Summer  1948       0     Gymnastics
# 50    1  32.0   175.0    64.0  FIN  1952 Summer  1952       0     Gymnastics
# 60    1  20.0   176.0    85.0  NOR  1992 Winter  1992       1  Alpine Skiing
#
#                                      Event  Medal
# 3              Tug-Of-War Men's Tug-Of-War      3
# 37  Swimming Men's 200 metres Breaststroke      1
# 38  Swimming Men's 400 metres Breaststroke      1
# 40             Ice Hockey Men's Ice Hockey      1
# 41  Gymnastics Men's Individual All-Around      1
# 42        Gymnastics Men's Team All-Around      3
# 44            Gymnastics Men's Horse Vault      3
# 48        Gymnastics Men's Pommelled Horse      3
# 50        Gymnastics Men's Team All-Around      1
# 60             Alpine Skiing Men's Super G      3

# %%
# In the ‘NOC’ column, convert all of the ‘FRG’s to ‘GER’ and convert all of the ’GDR’s to ’GER’.
pk['NOC'].replace({"FRG": "GER", "GDR": "GER"}, inplace=True)
print(pk)
# Out:
#         Sex   Age  Height  Weight  NOC        Games  Year  Season       Sport  \
# 3         1  34.0     NaN     NaN  DEN  1900 Summer  1900       0  Tug-Of-War
# 37        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 38        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 40        1  28.0   184.0    85.0  FIN  2014 Winter  2014       1  Ice Hockey
# 41        1  28.0   175.0    64.0  FIN  1948 Summer  1948       0  Gymnastics
# ...     ...   ...     ...     ...  ...          ...   ...     ...         ...
# 271078    0  25.0   168.0    80.0  URS  1956 Summer  1956       0   Athletics
# 271080    0  33.0   168.0    80.0  URS  1964 Summer  1964       0   Athletics
# 271082    1  28.0   182.0    82.0  POL  1980 Summer  1980       0     Fencing
# 271102    0  19.0   171.0    64.0  RUS  2000 Summer  2000       0   Athletics
# 271103    0  23.0   171.0    64.0  RUS  2004 Summer  2004       0   Athletics
#
#                                          Event  Medal
# 3                  Tug-Of-War Men's Tug-Of-War      3
# 37      Swimming Men's 200 metres Breaststroke      1
# 38      Swimming Men's 400 metres Breaststroke      1
# 40                 Ice Hockey Men's Ice Hockey      1
# 41      Gymnastics Men's Individual All-Around      1
# ...                                        ...    ...
# 271078              Athletics Women's Shot Put      2
# 271080              Athletics Women's Shot Put      1
# 271082                Fencing Men's Foil, Team      1
# 271102  Athletics Women's 4 x 400 metres Relay      1
# 271103  Athletics Women's 4 x 400 metres Relay      2
#
# [39783 rows x 11 columns]

# %%
# remove all the rows which have ‘NOC’ equals ‘URS’ or ‘RUS’.
pk = pk[pk["NOC"].str.contains("URS|RUS") == False]
print(pk)
# Out:
#         Sex   Age  Height  Weight  NOC        Games  Year  Season       Sport  \
# 3         1  34.0     NaN     NaN  DEN  1900 Summer  1900       0  Tug-Of-War
# 37        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 38        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 40        1  28.0   184.0    85.0  FIN  2014 Winter  2014       1  Ice Hockey
# 41        1  28.0   175.0    64.0  FIN  1948 Summer  1948       0  Gymnastics
# ...     ...   ...     ...     ...  ...          ...   ...     ...         ...
# 271032    0  22.0   181.0    78.0  NED  1996 Summer  1996       0        Judo
# 271046    1  21.0   175.0    70.0  POL  1980 Summer  1980       0   Athletics
# 271048    1  27.0   197.0    93.0  NED  1992 Summer  1992       0      Rowing
# 271049    1  31.0   197.0    93.0  NED  1996 Summer  1996       0      Rowing
# 271082    1  28.0   182.0    82.0  POL  1980 Summer  1980       0     Fencing
#
#                                          Event  Medal
# 3                  Tug-Of-War Men's Tug-Of-War      3
# 37      Swimming Men's 200 metres Breaststroke      1
# 38      Swimming Men's 400 metres Breaststroke      1
# 40                 Ice Hockey Men's Ice Hockey      1
# 41      Gymnastics Men's Individual All-Around      1
# ...                                        ...    ...
# 271032               Judo Women's Middleweight      1
# 271046    Athletics Men's 4 x 100 metres Relay      2
# 271048              Rowing Men's Double Sculls      1
# 271049               Rowing Men's Coxed Eights      3
# 271082                Fencing Men's Foil, Team      1
#
# [36115 rows x 11 columns]

# %%
pk.head(40)
# Out:
#      Sex   Age  Height  Weight  NOC        Games  Year  Season          Sport  \
# 3      1  34.0     NaN     NaN  DEN  1900 Summer  1900       0     Tug-Of-War
# 37     1  30.0     NaN     NaN  FIN  1920 Summer  1920       0       Swimming
# 38     1  30.0     NaN     NaN  FIN  1920 Summer  1920       0       Swimming
# 40     1  28.0   184.0    85.0  FIN  2014 Winter  2014       1     Ice Hockey
# 41     1  28.0   175.0    64.0  FIN  1948 Summer  1948       0     Gymnastics
# 42     1  28.0   175.0    64.0  FIN  1948 Summer  1948       0     Gymnastics
# 44     1  28.0   175.0    64.0  FIN  1948 Summer  1948       0     Gymnastics
# 48     1  28.0   175.0    64.0  FIN  1948 Summer  1948       0     Gymnastics
# 50     1  32.0   175.0    64.0  FIN  1952 Summer  1952       0     Gymnastics
# 60     1  20.0   176.0    85.0  NOR  1992 Winter  1992       1  Alpine Skiing
# 61     1  20.0   176.0    85.0  NOR  1992 Winter  1992       1  Alpine Skiing
# 63     1  22.0   176.0    85.0  NOR  1994 Winter  1994       1  Alpine Skiing
# 64     1  22.0   176.0    85.0  NOR  1994 Winter  1994       1  Alpine Skiing
# 67     1  22.0   176.0    85.0  NOR  1994 Winter  1994       1  Alpine Skiing
# 73     1  30.0   176.0    85.0  NOR  2002 Winter  2002       1  Alpine Skiing
# 76     1  30.0   176.0    85.0  NOR  2002 Winter  2002       1  Alpine Skiing
# 78     1  34.0   176.0    85.0  NOR  2006 Winter  2006       1  Alpine Skiing
# 79     0  27.0   163.0     NaN  NOR  2008 Summer  2008       0       Handball
# 86     1  24.0     NaN     NaN  NOR  1920 Summer  1920       0     Gymnastics
# 91     0  22.0     NaN     NaN  NED  1988 Summer  1988       0         Hockey
# 92     1  26.0   189.0    72.0  NED  1996 Summer  1996       0         Rowing
# 105    0  23.0   182.0    64.0  NOR  1996 Summer  1996       0       Football
# 106    1  20.0     NaN     NaN  NOR  1920 Summer  1920       0     Gymnastics
# 110    1  23.0     NaN     NaN  NOR  1952 Winter  1952       1  Speed Skating
# 113    1  31.0     NaN     NaN  NOR  1960 Winter  1960       1  Speed Skating
# 117    1  25.0     NaN     NaN  NOR  1912 Summer  1912       0        Sailing
# 150    1  21.0     NaN     NaN  FRA  1956 Summer  1956       0        Cycling
# 158    1  21.0   198.0    90.0  ITA  2016 Summer  2016       0         Rowing
# 159    1  30.0   194.0    87.0  ESP  2008 Summer  2008       0        Fencing
# 161    0  21.0   165.0    49.0  AZE  2016 Summer  2016       0      Taekwondo
# 172    1  28.0   180.0    83.0  BLR  2008 Summer  2008       0       Canoeing
# 173    1  23.0   182.0    86.0  FRA  2008 Summer  2008       0       Handball
# 174    1  27.0   182.0    86.0  FRA  2012 Summer  2012       0       Handball
# 175    1  31.0   182.0    86.0  FRA  2016 Summer  2016       0       Handball
# 178    1  22.0   185.0    82.0  CMR  2000 Summer  2000       0       Football
# 182    1  22.0   186.0    83.0  ESP  1996 Summer  1996       0     Water Polo
# 186    1  26.0   165.0    55.0  USA  2004 Summer  2004       0      Wrestling
# 188    1  28.0   181.0    82.0  ESP  1980 Summer  1980       0        Sailing
# 191    1  26.0   182.0    67.0  ESP  1984 Summer  1984       0      Athletics
# 200    1  38.0   190.0    85.0  FRA  2008 Summer  2008       0       Handball
#
#                                              Event  Medal
# 3                      Tug-Of-War Men's Tug-Of-War      3
# 37          Swimming Men's 200 metres Breaststroke      1
# 38          Swimming Men's 400 metres Breaststroke      1
# 40                     Ice Hockey Men's Ice Hockey      1
# 41          Gymnastics Men's Individual All-Around      1
# 42                Gymnastics Men's Team All-Around      3
# 44                    Gymnastics Men's Horse Vault      3
# 48                Gymnastics Men's Pommelled Horse      3
# 50                Gymnastics Men's Team All-Around      1
# 60                     Alpine Skiing Men's Super G      3
# 61                Alpine Skiing Men's Giant Slalom      1
# 63                    Alpine Skiing Men's Downhill      2
# 64                     Alpine Skiing Men's Super G      1
# 67                    Alpine Skiing Men's Combined      2
# 73                     Alpine Skiing Men's Super G      3
# 76                    Alpine Skiing Men's Combined      3
# 78                     Alpine Skiing Men's Super G      3
# 79                       Handball Women's Handball      3
# 86   Gymnastics Men's Team All-Around, Free System      2
# 91                           Hockey Women's Hockey      1
# 92          Rowing Men's Lightweight Double Sculls      2
# 105                      Football Women's Football      1
# 106  Gymnastics Men's Team All-Around, Free System      2
# 110               Speed Skating Men's 1,500 metres      1
# 113               Speed Skating Men's 1,500 metres      3
# 117                         Sailing Mixed 8 metres      3
# 150                  Cycling Men's Road Race, Team      3
# 158                     Rowing Men's Coxless Pairs      1
# 159                 Fencing Men's epee, Individual      1
# 161                    Taekwondo Women's Flyweight      1
# 172       Canoeing Men's Kayak Fours, 1,000 metres      3
# 173                        Handball Men's Handball      3
# 174                        Handball Men's Handball      3
# 175                        Handball Men's Handball      2
# 178                        Football Men's Football      3
# 182                    Water Polo Men's Water Polo      3
# 186       Wrestling Men's Featherweight, Freestyle      2
# 188    Sailing Mixed Two Person Heavyweight Dinghy      3
# 191                   Athletics Men's 1,500 metres      1
# 200                        Handball Men's Handball      3

# %%
# Remove all ‘NOC’ which appear less than 100 times.
x = pk.NOC.value_counts()
print(x)
# Out:
# USA    5637
# GER    3756
# GBR    2068
# FRA    1777
# ITA    1637
#        ...
# AHO       1
# GUA       1
# IRQ       1
# GUY       1
# TGA       1
# Name: NOC, Length: 145, dtype: int64

# %%
rem = x[x < 100].index
pk = pk[~pk.NOC.isin(rem)]
print(pk)
# Out:
#         Sex   Age  Height  Weight  NOC        Games  Year  Season       Sport  \
# 3         1  34.0     NaN     NaN  DEN  1900 Summer  1900       0  Tug-Of-War
# 37        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 38        1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 40        1  28.0   184.0    85.0  FIN  2014 Winter  2014       1  Ice Hockey
# 41        1  28.0   175.0    64.0  FIN  1948 Summer  1948       0  Gymnastics
# ...     ...   ...     ...     ...  ...          ...   ...     ...         ...
# 271032    0  22.0   181.0    78.0  NED  1996 Summer  1996       0        Judo
# 271046    1  21.0   175.0    70.0  POL  1980 Summer  1980       0   Athletics
# 271048    1  27.0   197.0    93.0  NED  1992 Summer  1992       0      Rowing
# 271049    1  31.0   197.0    93.0  NED  1996 Summer  1996       0      Rowing
# 271082    1  28.0   182.0    82.0  POL  1980 Summer  1980       0     Fencing
#
#                                          Event  Medal
# 3                  Tug-Of-War Men's Tug-Of-War      3
# 37      Swimming Men's 200 metres Breaststroke      1
# 38      Swimming Men's 400 metres Breaststroke      1
# 40                 Ice Hockey Men's Ice Hockey      1
# 41      Gymnastics Men's Individual All-Around      1
# ...                                        ...    ...
# 271032               Judo Women's Middleweight      1
# 271046    Athletics Men's 4 x 100 metres Relay      2
# 271048              Rowing Men's Double Sculls      1
# 271049               Rowing Men's Coxed Eights      3
# 271082                Fencing Men's Foil, Team      1
#
# [34237 rows x 11 columns]

# %%
pk.shape
# Out:
# (34237, 11)

# %%
pk.head()
# Out:
#     Sex   Age  Height  Weight  NOC        Games  Year  Season       Sport  \
# 3     1  34.0     NaN     NaN  DEN  1900 Summer  1900       0  Tug-Of-War
# 37    1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 38    1  30.0     NaN     NaN  FIN  1920 Summer  1920       0    Swimming
# 40    1  28.0   184.0    85.0  FIN  2014 Winter  2014       1  Ice Hockey
# 41    1  28.0   175.0    64.0  FIN  1948 Summer  1948       0  Gymnastics
#
#                                      Event  Medal
# 3              Tug-Of-War Men's Tug-Of-War      3
# 37  Swimming Men's 200 metres Breaststroke      1
# 38  Swimming Men's 400 metres Breaststroke      1
# 40             Ice Hockey Men's Ice Hockey      1
# 41  Gymnastics Men's Individual All-Around      1

# %%
# Create a histogram of the frequency of countries against number of medals using 10 bins.
x = pk["NOC"]
y = pk["Medal"]
plt.hist(x,bins=10,edgecolor='blue')
plt.title('Countries with number of medals')
plt.xlabel('Countries')
plt.ylabel('Medals')


plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %%
med = pk[["NOC", "Medal"]]
print(med)
# Out:
#         NOC  Medal
# 3       DEN      3
# 37      FIN      1
# 38      FIN      1
# 40      FIN      1
# 41      FIN      1
# ...     ...    ...
# 271032  NED      1
# 271046  POL      2
# 271048  NED      1
# 271049  NED      3
# 271082  POL      1
#
# [34237 rows x 2 columns]

# %%
gold = med[med['Medal'] > 2]
print(gold)
# Out:
#         NOC  Medal
# 3       DEN      3
# 42      FIN      3
# 44      FIN      3
# 48      FIN      3
# 60      NOR      3
# ...     ...    ...
# 270917  SUI      3
# 270970  BLR      3
# 271009  GER      3
# 271016  NED      3
# 271049  NED      3
#
# [11437 rows x 2 columns]

# %%
# Create a histrogram of the number of countries with gold medals using 10 bins. 
x = gold["NOC"]
y = gold["Medal"]
plt.hist(x,bins=10,edgecolor='white')
plt.title('Countries with number of gold medals')
plt.xlabel('Countries')
plt.ylabel('Medals')

plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %%
qq = pk.groupby(["NOC","Medal"])["Medal"].count()
print(qq)
# Out:
# NOC  Medal
# ARG  1          91
#      2          92
#      3          91
# AUS  1         517
#      2         455
#               ...
# USA  2        1641
#      3        2638
# YUG  1          93
#      2         167
#      3         130
# Name: Medal, Length: 123, dtype: int64

# %%
qq = pk.groupby(["NOC","Medal"])["Medal"].sum()
print(qq)
# Out:
# NOC  Medal
# ARG  1          91
#      2         184
#      3         273
# AUS  1         517
#      2         910
#               ...
# USA  2        3282
#      3        7914
# YUG  1          93
#      2         334
#      3         390
# Name: Medal, Length: 123, dtype: int64

# %%
points=pk.groupby(['NOC'])['Medal'].sum()
points.head()
# Out:
# NOC
# ARG     548
# AUS    2471
# AUT     852
# BEL     861
# BLR     231
# Name: Medal, dtype: int64

# %%
ee = pd.DataFrame(points)

ee['NOC'] = ee.index
ee.insert(loc=2, column='Points', value=points)

ee.head()
# Out:
#      Medal  NOC  Points
# NOC
# ARG    548  ARG     548
# AUS   2471  AUS    2471
# AUT    852  AUT     852
# BEL    861  BEL     861
# BLR    231  BLR     231

# %%
u = ee.reset_index(drop=True)
v = u.drop(u.columns[0], axis=1)
print(v.head())
# Out:
#    NOC  Points
# 0  ARG     548
# 1  AUS    2471
# 2  AUT     852
# 3  BEL     861
# 4  BLR     231

# %%
y = v["Points"]

plt.hist(x,bins=10,edgecolor='pink')
plt.title('Countries with Points')
plt.xlabel('Countries')
plt.ylabel('Points')

plt.xticks(rotation=90)
plt.show()
